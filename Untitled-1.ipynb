# %%
import pandas as pd
import pickle
from datetime import datetime

class DataExtractor:
    def __init__(self, invoice_file, expired_file):
        self.invoice_file = invoice_file
        self.expired_file = expired_file
        self.invoices = None
        self.expired_ids = None

    def load_data(self):
        try:
            # Load the pickled invoices
            with open(self.invoice_file, 'rb') as f:
                self.invoices = pickle.load(f)
            print("Invoices loaded successfully.")
        except Exception as e:
            print(f"Error loading invoices: {e}")

        try:
            # Load the expired invoice IDs
            with open(self.expired_file, 'r') as f:
                self.expired_ids = [int(line.strip()) for line in f.read().split(',')]
            print("Expired invoice IDs loaded successfully.")
        except Exception as e:
            print(f"Error loading expired invoice IDs: {e}")

    def transform_data(self):
        # Define the conversion table for invoice item types
        type_conversion = {0: 'Material', 1: 'Equipment', 2: 'Service', 3: 'Other'}
        
        # Prepare a list to hold the flattened data
        flattened_data = []

        # Inspect the structure of the first few invoices
        print("Inspecting the structure of the first few invoices:")
        for i, invoice in enumerate(self.invoices[:5]):
            print(f"Invoice {i}: {invoice}")
        
        for invoice in self.invoices:
            try:
                invoice_id = invoice['id']
                created_on = pd.to_datetime(invoice.get('creation_date', '1970-01-01'))  # Use a default date if key is missing
                invoice_total = sum(item['unit_price'] * item['quantity'] for item in invoice['items'])
                is_expired = invoice_id in self.expired_ids

                for item in invoice['items']:
                    invoiceitem_id = item['id']
                    invoiceitem_name = item['name']
                    item_type = type_conversion[item['type']]
                    unit_price = item['unit_price']
                    quantity = item['quantity']
                    total_price = unit_price * quantity
                    percentage_in_invoice = total_price / invoice_total

                    flattened_data.append({
                        'invoice_id': invoice_id,
                        'created_on': created_on,
                        'invoiceitem_id': invoiceitem_id,
                        'invoiceitem_name': invoiceitem_name,
                        'type': item_type,
                        'unit_price': unit_price,
                        'total_price': total_price,
                        'percentage_in_invoice': percentage_in_invoice,
                        'is_expired': is_expired
                    })
            except KeyError as e:
                print(f"KeyError for invoice {invoice.get('id', 'unknown')}: missing key {e}")
            except Exception as e:
                print(f"Unexpected error for invoice {invoice.get('id', 'unknown')}: {e}")

        # Create a DataFrame from the flattened data
        df = pd.DataFrame(flattened_data)

        # Debug: Print the DataFrame before sorting
        print("DataFrame before sorting:")
        print(df.head())

        # Sort the DataFrame by invoice_id and invoiceitem_id
        df.sort_values(by=['invoice_id', 'invoiceitem_id'], inplace=True)
        return df

    def save_to_csv(self, df, output_file):
        df.to_csv(output_file, index=False)

# Initialize and run the DataExtractor
extractor = DataExtractor(
    r"C:\Users\arman.manoukyan\OneDrive\Desktop\data\invoices_new.pkl", 
    r"C:\Users\arman.manoukyan\OneDrive\Desktop\data\expired_invoices.txt"
)
extractor.load_data()
df = extractor.transform_data()
extractor.save_to_csv(df, 'output.csv')
# Out:
# Invoices loaded successfully.
# Expired invoice IDs loaded successfully.
# Inspecting the structure of the first few invoices:
# Invoice 0: {'id': '365371O', 'created_on': '2019-05-27', 'items': [{'item': {'id': 142446, 'name': 'ii_142446', 'unit_price': 182, 'type': 1}, 'quantity': 6}, {'item': {'id': 154019, 'name': 'ii_154019', 'unit_price': 176, 'type': 1}, 'quantity': 1}]}
# Invoice 1: {'id': 389528, 'created_on': '2019-03-19', 'items': [{'item': {'id': 172535, 'name': 'ii_172535', 'unit_price': 105, 'type': 0}, 'quantity': 4}, {'item': {'id': 175208, 'name': 'ii_175208', 'unit_price': 109, 'type': 0}, 'quantity': 7}, {'item': {'id': 139970, 'name': 'ii_139970', 'unit_price': 193, 'type': 2}, 'quantity': 4}, {'item': {'id': 156273, 'name': 'ii_156273', 'unit_price': 129, 'type': 2}, 'quantity': 6}, {'item': {'id': 178512, 'name': 'ii_178512', 'unit_price': 108, 'type': 1}, 'quantity': 7}, {'item': {'id': 191045, 'name': 'ii_191045', 'unit_price': 195, 'type': 1}, 'quantity': 8}, {'item': {'id': 189841, 'name': 'ii_189841', 'unit_price': 171, 'type': 1}, 'quantity': 4}]}
# Invoice 2: {'id': 341762, 'created_on': '2019-06-19', 'items': [{'item': {'id': 143176, 'name': 'ii_143176', 'unit_price': 175, 'type': 2}, 'quantity': 2}, {'item': {'id': 161765, 'name': 'ii_161765', 'unit_price': 170, 'type': 2}, 'quantity': 8}, {'item': {'id': 167763, 'name': 'ii_167763', 'unit_price': 150, 'type': 3}, 'quantity': 5}, {'item': {'id': 195203, 'name': 'ii_195203', 'unit_price': 194, 'type': 0}, 'quantity': 3}, {'item': {'id': 188321, 'name': 'ii_188321', 'unit_price': 101, 'type': 3}, 'quantity': 1}, {'item': {'id': 114990, 'name': 'ii_114990', 'unit_price': 132, 'type': 3}, 'quantity': 2}, {'item': {'id': 126940, 'name': 'ii_126940', 'unit_price': 166, 'type': 0}, 'quantity': 3}]}
# Invoice 3: {'id': 319405, 'created_on': '2019-03-27', 'items': [{'item': {'id': 141009, 'name': 'ii_141009', 'unit_price': 161, 'type': 0}, 'quantity': 1}, {'item': {'id': 195216, 'name': 'ii_195216', 'unit_price': 140, 'type': 2}, 'quantity': 2}, {'item': {'id': 108059, 'name': 'ii_108059', 'unit_price': 118, 'type': 2}, 'quantity': 6}, {'item': {'id': 171459, 'name': 'ii_171459', 'unit_price': 187, 'type': 3}, 'quantity': 1}]}
# Invoice 4: {'id': 343695, 'created_on': '2019-04-10', 'items': [{'item': {'id': 144025, 'name': 'ii_144025', 'unit_price': 101, 'type': 3}, 'quantity': 'ten'}, {'item': {'id': 147038, 'name': 'ii_147038', 'unit_price': 177, 'type': 0}, 'quantity': 1}]}
# KeyError for invoice 365371O: missing key 'unit_price'
# KeyError for invoice 389528: missing key 'unit_price'
# KeyError for invoice 341762: missing key 'unit_price'
# KeyError for invoice 319405: missing key 'unit_price'
# KeyError for invoice 343695: missing key 'unit_price'
# KeyError for invoice 358095: missing key 'unit_price'
# KeyError for invoice 381281: missing key 'unit_price'
# KeyError for invoice 352391: missing key 'unit_price'
# KeyError for invoice 374089O: missing key 'unit_price'
# KeyError for invoice 331193: missing key 'unit_price'
# KeyError for invoice 347510: missing key 'unit_price'
# KeyError for invoice 307175: missing key 'unit_price'
# KeyError for invoice 369378: missing key 'unit_price'
# KeyError for invoice 377307: missing key 'unit_price'
# KeyError for invoice 367288: missing key 'unit_price'
# KeyError for invoice 337140: missing key 'unit_price'
# KeyError for invoice 315960: missing key 'unit_price'
# KeyError for invoice 340601: missing key 'unit_price'
# KeyError for invoice 397723O: missing key 'unit_price'
# KeyError for invoice 379687: missing key 'unit_price'
# KeyError for invoice 309022: missing key 'unit_price'
# KeyError for invoice 325156O: missing key 'unit_price'
# KeyError for invoice 316710: missing key 'unit_price'
# KeyError for invoice 370388: missing key 'unit_price'
# KeyError for invoice 307923: missing key 'unit_price'
# KeyError for invoice 326649O: missing key 'unit_price'
# KeyError for invoice 369292: missing key 'unit_price'
# KeyError for invoice 304245: missing key 'unit_price'
# KeyError for invoice 392733: missing key 'unit_price'
# KeyError for invoice 335732: missing key 'unit_price'
# KeyError for invoice 363284: missing key 'unit_price'
# KeyError for invoice 373241: missing key 'unit_price'
# KeyError for invoice 379961: missing key 'items'
# KeyError for invoice 385290O: missing key 'unit_price'
# KeyError for invoice 394428: missing key 'unit_price'
# KeyError for invoice 326452: missing key 'unit_price'
# KeyError for invoice 342057: missing key 'unit_price'
# KeyError for invoice 356817: missing key 'unit_price'
# KeyError for invoice 381476O: missing key 'unit_price'
# KeyError for invoice 322229: missing key 'unit_price'
# KeyError for invoice 377719: missing key 'unit_price'
# KeyError for invoice 389694: missing key 'unit_price'
# KeyError for invoice 371205: missing key 'unit_price'
# KeyError for invoice 373470: missing key 'unit_price'
# KeyError for invoice 352442: missing key 'unit_price'
# KeyError for invoice 331601: missing key 'unit_price'
# KeyError for invoice 338547: missing key 'unit_price'
# KeyError for invoice 350506: missing key 'items'
# KeyError for invoice 392657: missing key 'unit_price'
# KeyError for invoice 377572: missing key 'unit_price'
# KeyError for invoice 324751: missing key 'unit_price'
# KeyError for invoice 347243: missing key 'unit_price'
# KeyError for invoice 344265: missing key 'unit_price'
# KeyError for invoice 349879: missing key 'unit_price'
# KeyError for invoice 335226O: missing key 'unit_price'
# KeyError for invoice 383681: missing key 'unit_price'
# KeyError for invoice 385661: missing key 'unit_price'
# KeyError for invoice 348894: missing key 'unit_price'
# KeyError for invoice 378746: missing key 'unit_price'
# KeyError for invoice 374733: missing key 'unit_price'
# KeyError for invoice 301695: missing key 'unit_price'
# KeyError for invoice 351096: missing key 'unit_price'
# KeyError for invoice 308939: missing key 'unit_price'
# KeyError for invoice 379387: missing key 'unit_price'
# KeyError for invoice 371786O: missing key 'unit_price'
# KeyError for invoice 356532: missing key 'unit_price'
# KeyError for invoice 331902O: missing key 'unit_price'
# KeyError for invoice 328581: missing key 'unit_price'
# KeyError for invoice 325063: missing key 'unit_price'
# KeyError for invoice 375121: missing key 'unit_price'
# KeyError for invoice 368913: missing key 'unit_price'
# KeyError for invoice 383182: missing key 'unit_price'
# KeyError for invoice 308237O: missing key 'unit_price'
# KeyError for invoice 376944: missing key 'unit_price'
# KeyError for invoice 378408: missing key 'unit_price'
# KeyError for invoice 315942: missing key 'unit_price'
# KeyError for invoice 383281: missing key 'unit_price'
# KeyError for invoice 363263: missing key 'unit_price'
# KeyError for invoice 369103: missing key 'unit_price'
# KeyError for invoice 383235: missing key 'unit_price'
# KeyError for invoice 323231: missing key 'unit_price'
# KeyError for invoice 340299O: missing key 'unit_price'
# KeyError for invoice 395841: missing key 'unit_price'
# KeyError for invoice 391273: missing key 'unit_price'
# KeyError for invoice 366751: missing key 'unit_price'
# KeyError for invoice 313012: missing key 'unit_price'
# KeyError for invoice 311671: missing key 'unit_price'
# KeyError for invoice 381457: missing key 'unit_price'
# KeyError for invoice 343254: missing key 'unit_price'
# KeyError for invoice 330931: missing key 'unit_price'
# KeyError for invoice 375592: missing key 'unit_price'
# KeyError for invoice 386678: missing key 'unit_price'
# KeyError for invoice 360664: missing key 'unit_price'
# KeyError for invoice 387341: missing key 'unit_price'
# KeyError for invoice 305869: missing key 'unit_price'
# KeyError for invoice 356552: missing key 'unit_price'
# KeyError for invoice 306163: missing key 'unit_price'
# KeyError for invoice 373375O: missing key 'unit_price'
# KeyError for invoice 321243: missing key 'unit_price'
# KeyError for invoice 377960: missing key 'unit_price'
# DataFrame before sorting:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 93
#      88 extractor = DataExtractor(
#      89     r"C:\Users\arman.manoukyan\OneDrive\Desktop\data\invoices_new.pkl",
#      90     r"C:\Users\arman.manoukyan\OneDrive\Desktop\data\expired_invoices.txt"
#      91 )
#      92 extractor.load_data()
# ---> 93 df = extractor.transform_data()
#      94 extractor.save_to_csv(df, 'output.csv')
#
# Cell In[14], line 81, in DataExtractor.transform_data(self)
#      78 print(df.head())
#      80 # Sort the DataFrame by invoice_id and invoiceitem_id
# ---> 81 df.sort_values(by=['invoice_id', 'invoiceitem_id'], inplace=True)
#      82 return df
#
# File c:\Users\arman.manoukyan\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\arman.manoukyan\anaconda3\Lib\site-packages\pandas\core\frame.py:6894, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6888     raise ValueError(
#    6889         f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6890         f" != length of by ({len(by)})"
#    6891     )
#    6892 if len(by) > 1:
# -> 6894     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6896     # need to rewrap columns in Series to apply key function
#    6897     if key is not None:
#    6898         # error: List comprehension has incompatible type List[Series];
#    6899         # expected List[ndarray]
#
# File c:\Users\arman.manoukyan\anaconda3\Lib\site-packages\pandas\core\frame.py:6894, in <listcomp>(.0)
#    6888     raise ValueError(
#    6889         f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6890         f" != length of by ({len(by)})"
#    6891     )
#    6892 if len(by) > 1:
# -> 6894     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6896     # need to rewrap columns in Series to apply key function
#    6897     if key is not None:
#    6898         # error: List comprehension has incompatible type List[Series];
#    6899         # expected List[ndarray]
#
# File c:\Users\arman.manoukyan\anaconda3\Lib\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'invoice_id'
